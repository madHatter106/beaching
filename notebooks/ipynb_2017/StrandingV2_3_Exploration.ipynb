# %%
import pandas as pd
import numpy as np
import pathlib
import matplotlib.pyplot as pl
from matplotlib import rcParams
from pandas.plotting import scatter_matrix

# %%
# %matplotlib inline

# %%
# Load the dataset:
home = pathlib.Path.home()
fpath = home / 'DATA/Beaching_Project/PklJar/dfStrandDailyCleanCompact.pkl'

# %%
dfStrandCompactDaily = pd.read_pickle(fpath)

# %%
dfStrandCompactDaily
# Out:
#              NUM_ANIMALS  SPECIES_Delphinus delphis  \
# REPORT_DATE
# 1999-03-07          11.0                        0.0
# 1999-03-08           0.0                        0.0
# 1999-03-09           0.0                        0.0
# 1999-03-10           0.0                        0.0
# 1999-03-11           0.0                        0.0
# 1999-03-12           0.0                        0.0
# 1999-03-13           0.0                        0.0
# 1999-03-14           0.0                        0.0
# 1999-03-15           0.0                        0.0
# 1999-03-16           0.0                        0.0
# 1999-03-17           0.0                        0.0
# 1999-03-18           5.0                        0.0
# 1999-03-19          29.0                        0.0
# 1999-03-20          12.0                        0.0
# 1999-03-21           2.0                        0.0
# 1999-03-22           2.0                        0.0
# 1999-03-23           0.0                        0.0
# ...
