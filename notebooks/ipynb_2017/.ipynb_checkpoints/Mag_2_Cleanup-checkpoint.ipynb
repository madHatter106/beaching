# %%
import pandas as pd
import os
import glob
import numpy as np
% matplotlib inline

# %%
PKLDIR = '../PklJar/'

# %%
dfMag = pd.read_pickle(os.path.join(PKLDIR, 'dfMagDaily.pkl'))

# %%
dfMag.plot(y=['FRDH', 'OTTH'], figsize=(13,6), marker='.', ls=':');

# %%
dfMag.head()
# Out:
#                     FRDH          FRDV          OTTH          OTTV
# DATE_TIME
# 1999-01-01  20999.987708  49201.519653  17459.028474  53549.040000
# 1999-01-02  20995.609097  49202.668125  17455.841440  53548.428889
# 1999-01-03  21050.438681  52278.752361  17458.259553  53551.839861
# 1999-01-04  21101.213611  49311.501111  17453.573850  53549.170278
# 1999-01-05  20985.217292  49205.891597  17447.151464  53554.155208

# %%
dfMag.describe()
# Out:
#                 FRDH          FRDV           OTTH          OTTV
# count    5844.000000   5844.000000    5479.000000   5479.000000
# mean    22209.519903  48569.323283   18596.959816  52784.058350
# std      8082.356739   4440.640472    7379.706478   2902.282171
# min     20810.878681  46697.858903   17351.674429  51500.003333
# 25%     21014.388328  47342.917587   17633.608423  52030.718264
# 50%     21150.902886  47989.982604   17811.659804  52547.622222
# 75%     21291.631247  48674.187587   18052.456247  53062.341319
# max    141419.942024  99999.000000  141419.942024  99999.000000

# %%
dfMag.replace(to_replace=99999, value=np.NaN, inplace=True)

# %%
dfMag.describe()
# Out:
#                 FRDH          FRDV           OTTH          OTTV
# count    5836.000000   5824.000000    5479.000000   5465.000000
# mean    22102.885934  48392.710382   18596.959816  52663.105160
# std      7556.868228   3266.667266    7379.706478   1648.741556
# min     20810.878681  46697.858903   17351.674429  51500.003333
# 25%     21014.314061  47341.060434   17633.608423  52030.123542
# 50%     21150.557272  47983.967187   17811.659804  52546.232500
# 75%     21291.375443  48667.408142   18052.456247  53059.596736
# max    141419.942024  98162.458889  141419.942024  94161.155903

# %%
dfMag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5844 entries, 1999-01-01 to 2014-12-31
# Data columns (total 4 columns):
# FRDH    5836 non-null float64
# FRDV    5824 non-null float64
# OTTH    5479 non-null float64
# OTTV    5465 non-null float64
# dtypes: float64(4)
# memory usage: 228.3 KB

# %%
dfMag.to_pickle('../PklJar/dfMagDaily.pkl')
