# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
from matplotlib import rcParams
from pandas.plotting import scatter_matrix

# %%
# %matplotlib inline

# %%
dfStrandCompactDaily = pd.read_pickle('../PklJar/dfStrandDailyCleanCompact.pkl')

# %%
f, ax=pl.subplots(figsize=(16, 16))
scatter_matrix(dfStrandCompactDaily.filter(like='SPECIES'), ax=ax);
# Out:
# /home/madhatter106/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2862: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dfStrandCompactDaily.head()
# Out:
#              NUM_ANIMALS  SPECIES_Delphinus delphis  \
# REPORT_DATE
# 1999-03-07          11.0                        0.0
# 1999-03-08           0.0                        0.0
# 1999-03-09           0.0                        0.0
# 1999-03-10           0.0                        0.0
# 1999-03-11           0.0                        0.0
#
#              SPECIES_Globicephala melas  SPECIES_Grampus griseus  \
# REPORT_DATE
# 1999-03-07                          0.0                      0.0
# 1999-03-08                          0.0                      0.0
# 1999-03-09                          0.0                      0.0
# 1999-03-10                          0.0                      0.0
# 1999-03-11                          0.0                      0.0
#
#              SPECIES_Lagenorhynchus acutus  SPECIES_Stenella coeruleoalba  \
# REPORT_DATE
# 1999-03-07                             6.0                            0.0
# ...
