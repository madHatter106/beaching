# %%
import pandas as pd
import numpy as np
from matplotlib import rcParams
import matplotlib.pyplot as pl
import seaborn as sb
import os
from tqdm import tqdm_notebook

# %%
# %matplotlib inline

# %%
sb.reset_defaults()
rcParams['xtick.labelsize'] = 14
rcParams['ytick.labelsize'] = 14
rcParams['font.size'] = 14
rcParams['figure.figsize'] = (10, 5)
rcParams['axes.formatter.limits'] = (-2, 3)

# %%
sb.set_style('darkgrid')

# %%
dataMain = '/home/madhatter106/DATA/Beaching_Project/CapeCodData/'
pklDir = os.path.join(dataMain, 'PklJar')

# %%
dfMonthlyIndex = pd.read_pickle(os.path.join(pklDir, 'dfMonthlyIndex.pkl'))

# %%
dfMonthlyIndex.plot()

# %%
dfMonthlyIndex.head()
# Out:
#             EasterlyPersistence  SoutherlyPersistence      WTMP      WVHT
# date
# 1999-01-31             1.651654             -1.652568 -0.902770  0.003083
# 1999-02-28             1.344675              0.709994 -0.406426  0.113401
# 1999-03-31            -1.077389             -0.124328 -0.842859  0.119464
# 1999-04-30            -1.123109              0.786388 -0.229210 -0.337769
# 1999-05-31             0.585007              0.071033  0.363703 -0.186472

# %%
dfMonthlyIndex.rename(columns={'SoutherlyPersistence': 'SoutherlyIdx', 'EasterlyPersistence': 'EasterlyIdx'},
                     inplace=True)

# %%
dfMonthlyIndex.plot(y='SoutherlyIdx', kind='line', ls=':', marker='.',figsize=(12,5));

# %%
dfMonthlyIndex.plot(y='EasterlyIdx', kind='line', ls=':', marker='.',figsize=(12,5))

# %%
dfMonthlyIndex.plot(y='WTMP', kind='line', ls=':', marker='.',figsize=(12,5))

# %%
dfMonthlyIndex.plot(y='WVHT', kind='line', ls=':', marker='.',figsize=(12,5))

# %%
f, ax = pl.subplots(figsize=(6,6))
sb.heatmap(dfMonthlyIndex.corr(), yticklabels=['E.Idx', 'S.Idx', 'WTMP', 'WVHT'],
           xticklabels=['E.Idx', 'S.Idx', 'WTMP', 'WVHT'], annot=True, ax=ax)
